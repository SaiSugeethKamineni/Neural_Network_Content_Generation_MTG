# %% [markdown]
# # Colour prediction for a MTG card image
#
# ---

# %% [markdown]
# ### Import necessary libraries

# %%
# !sudo pip install h5py
import h5py
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from scipy import misc
import glob
from google.colab import drive
import pickle
import pandas as pd
from sklearn import preprocessing
import collections
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.17.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ### Mount Google drive

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Unzip the data

# %%
# !unzip /content/gdrive/'My Drive'/'Magic Final Project'/data/images/cropped.zip
# Out:
# Archive:  /content/gdrive/My Drive/Magic Final Project/data/images/cropped.zip
# replace cropped/39934090-36a6-4183-9176-97ea932d2685.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
df = pd.read_csv("gdrive/My Drive/Magic Final Project/data/cards.csv")

# %%
df = df.sort_values('Unnamed: 0')
df = df.reset_index(drop=True)

# %%
df1 = pd.DataFrame(df['colors'][:23000])
mask = (df1['colors'].str.len() == 1)
df1 = df1.loc[mask]

# %%
sgl_clr_exists= np.array(df1.index)

# %%
collections.Counter(df1['colors'])
# Out:
# Counter({'B': 3255, 'G': 3235, 'R': 3270, 'U': 3287, 'W': 3253})

# %%
le = preprocessing.LabelEncoder()
le.fit(df1['colors'])
df1['color_code'] = le.transform(df1['colors'])

# %%
image_labels_val = list(df1['color_code'])

# %%
image_names = list(df.iloc[sgl_clr_exists,:]['Unnamed: 0'])
image_labels1 = list(df1['color_code'])

# %%
print(len(image_names), len(image_labels1))
# Out:
# 16300 16300

# %%
df1 = pd.DataFrame(df['colors'][23000:])
mask = (df1['colors'].str.len() == 1)
df1 = df1.loc[mask]

# %%
sgl_clr_exists= np.array(df1.index)

# %%
collections.Counter(df1['colors'])
# Out:
# Counter({'B': 214, 'G': 221, 'R': 211, 'U': 215, 'W': 233})

# %%
le = preprocessing.LabelEncoder()
le.fit(df1['colors'])
df1['color_code'] = le.transform(df1['colors'])

# %%
image_names_val = list(df.iloc[sgl_clr_exists,:]['Unnamed: 0'])
image_labels_test = list(df1['color_code'])

# %%
print(len(image_names_val), len(image_labels_test))
# Out:
# 1094 1094

# %%
data = np.zeros((16300, 452, 616, 3), dtype=np.dtype('u1'))
i = 0
for name in image_names:
    img = "cropped/"+name+".jpg"
    data[i] = np.array(Image.open(img))
    i += 1

# %%
test_data = np.zeros((1094, 452, 616, 3), dtype=np.dtype('u1'))
i = 0
for name in image_names_val:
    img = "cropped/"+name+".jpg"
    test_data[i] = np.array(Image.open(img))
    i += 1

# %%
def conc(l):
    return tf.keras.backend.concatenate((l[0], l[1]), axis=-1)

# %%
inp_k = tf.keras.layers.Input((452, 616, 3))
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', padding='same', input_shape=(452, 616, 3)),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, (3,3), strides=(2,2), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(32, (3,3), strides=(2,2), activation='relu', padding='same'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu')
])

m = model(inp_k)

test_model=tf.keras.models.Sequential([
    tf.keras.layers.GlobalAveragePooling2D(input_shape=((452, 616, 3)))
])
t = test_model(inp_k)

lam = tf.keras.layers.Lambda(conc, output_shape=(515,))([t, m])
intm = tf.keras.layers.Dense(64, activation='relu')(lam)
out = tf.keras.layers.Dense(5, activation='softmax')(intm)
Model = tf.keras.Model(inp_k, out)

opti = tf.train.AdamOptimizer(learning_rate=0.001)
Model.compile(optimizer=opti, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
Model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 452, 616, 3) 0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 3)            0           input_1[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 512)          4378048     input_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 515)          0           sequential_1[1][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           33024       lambda[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 5)            325         dense_1[0][0]
# ==================================================================================================
# Total params: 4,411,397
# Trainable params: 4,411,397
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
history = Model.fit(data, image_labels1, validation_split=0.05, batch_size=100, epochs=30, callbacks=[mc])
# Out:
# Train on 15485 samples, validate on 815 samples
# Epoch 1/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 4.5394 - acc: 0.3382
# Epoch 00001: val_acc improved from -inf to 0.39877, saving model to best_model.h5
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file. You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 15485/15485 [==============================] - 65s 4ms/sample - loss: 4.5225 - acc: 0.3388 - val_loss: 1.4541 - val_acc: 0.3988
# Epoch 2/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 1.4217 - acc: 0.4062
# Epoch 00002: val_acc did not improve from 0.39877
# 15485/15485 [==============================] - 58s 4ms/sample - loss: 1.4219 - acc: 0.4064 - val_loss: 1.5409 - val_acc: 0.3546
# Epoch 3/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 1.3573 - acc: 0.4497
# Epoch 00003: val_acc improved from 0.39877 to 0.40245, saving model to best_model.h5
# WARNING:tensorflow:TensorFlow optimizers do not make it possible to access optimizer attributes or optimizer state after instantiation. As a result, we cannot save the optimizer as part of the model save file. You will have to compile your model again after loading it. Prefer using a Keras optimizer instead (see keras.io/optimizers).
# 15485/15485 [==============================] - 58s 4ms/sample - loss: 1.3576 - acc: 0.4493 - val_loss: 1.4627 - val_acc: 0.4025
# Epoch 4/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 1.2559 - acc: 0.4986
# Epoch 00004: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 58s 4ms/sample - loss: 1.2559 - acc: 0.4985 - val_loss: 1.6359 - val_acc: 0.3755
# Epoch 5/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 1.0825 - acc: 0.5779
# Epoch 00005: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 58s 4ms/sample - loss: 1.0833 - acc: 0.5778 - val_loss: 1.7002 - val_acc: 0.3755
# Epoch 6/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.8231 - acc: 0.6897
# Epoch 00006: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 58s 4ms/sample - loss: 0.8238 - acc: 0.6893 - val_loss: 1.9509 - val_acc: 0.3509
# Epoch 7/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.5491 - acc: 0.8031
# Epoch 00007: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.5489 - acc: 0.8032 - val_loss: 2.5279 - val_acc: 0.3215
# Epoch 8/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.3342 - acc: 0.8871
# Epoch 00008: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.3341 - acc: 0.8871 - val_loss: 2.9360 - val_acc: 0.3178
# Epoch 9/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.2264 - acc: 0.9262
# Epoch 00009: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.2267 - acc: 0.9261 - val_loss: 3.3818 - val_acc: 0.3178
# Epoch 10/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.1472 - acc: 0.9550
# Epoch 00010: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.1480 - acc: 0.9546 - val_loss: 3.8044 - val_acc: 0.3055
# Epoch 11/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.1176 - acc: 0.9646
# Epoch 00011: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.1177 - acc: 0.9646 - val_loss: 4.2043 - val_acc: 0.2920
# Epoch 12/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0717 - acc: 0.9794
# Epoch 00012: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0718 - acc: 0.9793 - val_loss: 4.5801 - val_acc: 0.3092
# Epoch 13/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0503 - acc: 0.9873
# Epoch 00013: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0503 - acc: 0.9873 - val_loss: 4.7303 - val_acc: 0.2933
# Epoch 14/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0569 - acc: 0.9833
# Epoch 00014: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0569 - acc: 0.9833 - val_loss: 4.8157 - val_acc: 0.3153
# Epoch 15/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0947 - acc: 0.9691
# Epoch 00015: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0947 - acc: 0.9691 - val_loss: 5.1139 - val_acc: 0.3166
# Epoch 16/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0820 - acc: 0.9740
# Epoch 00016: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0820 - acc: 0.9741 - val_loss: 4.9089 - val_acc: 0.3104
# Epoch 17/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0696 - acc: 0.9771
# Epoch 00017: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0698 - acc: 0.9770 - val_loss: 5.0454 - val_acc: 0.3141
# Epoch 18/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0865 - acc: 0.9723
# Epoch 00018: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0866 - acc: 0.9724 - val_loss: 5.1003 - val_acc: 0.2957
# Epoch 19/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0561 - acc: 0.9836
# Epoch 00019: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0559 - acc: 0.9837 - val_loss: 5.4917 - val_acc: 0.3043
# Epoch 20/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.1004 - acc: 0.9684
# Epoch 00020: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.1010 - acc: 0.9684 - val_loss: 5.3964 - val_acc: 0.2969
# Epoch 21/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0462 - acc: 0.9851
# Epoch 00021: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0463 - acc: 0.9851 - val_loss: 6.1642 - val_acc: 0.3117
# Epoch 22/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0203 - acc: 0.9945
# Epoch 00022: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 57s 4ms/sample - loss: 0.0205 - acc: 0.9945 - val_loss: 6.4724 - val_acc: 0.3018
# Epoch 23/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0238 - acc: 0.9935
# Epoch 00023: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.0238 - acc: 0.9935 - val_loss: 6.4850 - val_acc: 0.2933
# Epoch 24/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0295 - acc: 0.9896
# Epoch 00024: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.0295 - acc: 0.9896 - val_loss: 6.6316 - val_acc: 0.3153
# Epoch 25/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0350 - acc: 0.9892
# Epoch 00025: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.0350 - acc: 0.9892 - val_loss: 6.6049 - val_acc: 0.3129
# Epoch 26/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0541 - acc: 0.9838
# Epoch 00026: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.0542 - acc: 0.9839 - val_loss: 6.8363 - val_acc: 0.2798
# Epoch 27/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.1016 - acc: 0.9682
# Epoch 00027: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.1021 - acc: 0.9678 - val_loss: 5.3590 - val_acc: 0.3117
# Epoch 28/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.1273 - acc: 0.9633
# Epoch 00028: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.1271 - acc: 0.9633 - val_loss: 5.9902 - val_acc: 0.3055
# Epoch 29/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0177 - acc: 0.9944
# Epoch 00029: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.0176 - acc: 0.9944 - val_loss: 6.3324 - val_acc: 0.3166
# Epoch 30/30
# 15400/15485 [============================>.] - ETA: 0s - loss: 0.0057 - acc: 0.9983
# Epoch 00030: val_acc did not improve from 0.40245
# 15485/15485 [==============================] - 56s 4ms/sample - loss: 0.0056 - acc: 0.9983 - val_loss: 6.8300 - val_acc: 0.2957

# %%
Model = tf.keras.models.load_model('best_model.h5')
Model.compile(optimizer=opti, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.

# %%
Model.evaluate(test_data, image_labels_test)
# Out:
# 1094/1094 [==============================] - 2s 2ms/sample - loss: 1.4792 - acc: 0.3784
# [1.4792107034209006, 0.37842777]
